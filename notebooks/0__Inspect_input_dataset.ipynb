# %%
import sys
sys.path.append('../')

# %%
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# %%
test_dataset = torch.load('../training_data/original/test_data.pt', weights_only=False, mmap=True)

# %%
test_dl = DataLoader(test_dataset, batch_size=1, shuffle=True)

# %%
batch = next(iter(test_dl))

# %%
pre_imgs, target = batch
#print(pre_imgs.shape, target.shape)
pre_imgs = pre_imgs.squeeze()
target = target.squeeze()
#pre_imgs.shape, target.shape

# %%
plt.imshow(target[0, ...])
plt.colorbar()

# %%
plt.imshow(target[1, ...])
plt.colorbar()

# %%
def plot_batch():
    return
